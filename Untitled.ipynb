# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("bengaluru_house_prices.csv")

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
sns.histplot(df["price"],kde = True)
# plt.xticks(rotation=90)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(df["size"])
plt.xticks(rotation=90)
plt.show()

# %%
df_new = df.drop(columns=["society","location","availability"])
df_new.isnull().sum()
# Out:
# area_type       0
# size           16
# total_sqft      0
# bath           73
# balcony       609
# price           0
# dtype: int64

# %%
df_new["area_type"].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
sns.barplot(df_new.groupby("area_type")["price"].mean())
# Out:
# <Axes: xlabel='area_type', ylabel='price'>

# %%
sns.barplot(df_new.groupby("area_type")["price"].max())
# Out:
# <Axes: xlabel='area_type', ylabel='price'>

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df_new["area_type"] = encoder.fit_transform(df_new["area_type"])

# %%
df_new["area_type"].value_counts()
# Out:
# area_type
# 3    8790
# 0    2418
# 2    2025
# 1      87
# Name: count, dtype: int64

# %%
def convert_area(data):
    if "-" in data:
        data = data.split("-")
        newdata = (eval(data[0])+eval(data[-1]))//2
        return int(newdata)
    else:
        newdata = ""
        for i in data:
            if i not in "0987654321":
                break
            else:
                newdata += i

        return int(newdata)



# ans = convert_area("2100.54 - 2856")
df_new["total_sqft"] = df_new["total_sqft"].apply(convert_area)
# print(ans)
# print(type(ans))

# %%
df_new["total_sqft"].dtype
# Out:
# dtype('int64')

# %%
sns.boxplot(df_new["total_sqft"])
# Out:
# <Axes: ylabel='total_sqft'>

# %%
plt.scatter(df_new["total_sqft"],df_new["price"])
plt.xlabel("total squarefit")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
# now remove some outlires
df_new = df_new[df_new["total_sqft"] < 20000]

# %%
plt.scatter(df_new["total_sqft"],df_new["price"])
plt.xlabel("total squarefit")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
df_new["balcony"].fillna(0,inplace=True)
# Out:
# /tmp/ipykernel_29033/667552788.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_new["balcony"].fillna(0,inplace=True)

# %%
df_new["balcony"].astype(int)
# Out:
# 0        1
# 1        3
# 2        3
# 3        1
# 4        1
#         ..
# 13315    0
# 13316    0
# 13317    1
# 13318    1
# 13319    1
# Name: balcony, Length: 13312, dtype: int64

# %%
df_new.dropna(inplace=True)

# %%
plt.scatter(df_new["bath"],df_new["total_sqft"])

# %%
df_new["size"].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
def convert_bhk(data):
    data = data.split()
    return int(data[0])
    
df_new["size"] = df_new["size"].apply(convert_bhk)

# %%
df_new
# Out:
#        area_type  size  total_sqft  bath  balcony   price
# 0              3     2        1056   2.0      1.0   39.07
# 1              2     4        2600   5.0      3.0  120.00
# 2              0     3        1440   2.0      3.0   62.00
# 3              3     3        1521   3.0      1.0   95.00
# 4              3     2        1200   2.0      1.0   51.00
# ...          ...   ...         ...   ...      ...     ...
# 13315          0     5        3453   4.0      0.0  231.00
# 13316          3     4        3600   5.0      0.0  400.00
# 13317          0     2        1141   2.0      1.0   60.00
# 13318          3     4        4689   4.0      1.0  488.00
# 13319          3     1         550   1.0      1.0   17.00
#
# [13239 rows x 6 columns]

# %%
sns.heatmap(df_new.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df_new)

# %%
x = df_new.iloc[:,:-1]
y = df_new.iloc[:,-1]

# %%
### now model building part

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((9929, 5), (3310, 5), (9929,), (3310,))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
scaler.var_
# Out:
# array([1.29962058e+00, 1.74003589e+00, 8.59172872e+05, 1.83462367e+00,
#        7.32013369e-01])

# %%
scaler.mean_
# Out:
# array([2.29721019e+00, 2.81246853e+00, 1.53002125e+03, 2.70178266e+00,
#        1.52029409e+00])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.svm import SVR

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,precision_score

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(x_train,y_train)
y_pred = lr_model.predict(x_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.5010147037344768

# %%
reciduals = y_test-y_pred
sns.distplot(reciduals)
# Out:
# /tmp/ipykernel_29033/2157047858.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(reciduals)
# <Axes: xlabel='price', ylabel='Density'>

# %%
rf_model = RandomForestRegressor(n_estimators=100)
rf_model.fit(x_train,y_train)
y_pred = rf_model.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.49246850140342147
# 38.25646104519114

# %%
reciduals = y_test-y_pred
sns.distplot(reciduals)
plt.show()
# Out:
# /tmp/ipykernel_29033/941911394.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(reciduals)

# %%
dt_model = DecisionTreeRegressor()
dt_model.fit(x_train,y_train)
y_pred = dt_model.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.19102849092822882
# 43.4929553233221

# %%
reciduals = y_test-y_pred
sns.histplot(reciduals,kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
gd_model = GradientBoostingRegressor(n_estimators=100)
gd_model.fit(x_train,y_train)
y_pred = gd_model.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.48311883228373387
# 38.71537935039594

# %%
reciduals = y_test-y_pred
sns.histplot(reciduals,kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sv_model = SVR()
sv_model.fit(x_train,y_train)
y_pred = sv_model.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.3169274698496831
# 42.06374342749881

# %%
reciduals = y_test-y_pred
sns.histplot(reciduals,kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
import pickle

# %%
pickle.dump(lr_model,open("model.pkl","wb"))
pickle.dump(scaler,open("scaler.pkl","wb"))
pickle.dump(df,open("data.pkl","wb"))
pickle.dump(df_new,open("df_new.pkl","wb"))

# %%
reciduals = y_test-y_pred
sns.histplot(reciduals,kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
print(np.__version__)
print(pd.__version__)
print(sklearn.__version__)
# Out:
# 2.3.1
# 2.3.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 3
#       1 print(np.__version__)
#       2 print(pd.__version__)
# ----> 3 print(sklearn.__version__)
#
# NameError: name 'sklearn' is not defined
